# %% [markdown]
# <img src="https://datascience.uc.cl/images/datapalooza2023.jpg" width="800">
#
# * Facultad de Matemáticas - Pontificia Universidad Católica de Chile.
# * Más información sobre nuestros programas en el siguiente [link](https://datascience.uc.cl/).

# %% [markdown]
# # EJERCICIOS: Introducción a `python`
#
# ---
#
#
# 1. Escriba un programa donde la consola te pregunte tu nombre y luego de introducirlo, se muestre en patalla la siguiente cadena: Moin <nombre>, welcome to Datapalooza!, donde <nombre> es tu nombre o el que se agregue

# %%
nombre = input("Introduce tu nombre: ")
print("")
print("Moin " + nombre + " welcome to Datapalooza!")
# Out:
# Introduce tu nombre: Kate
#
# Moin Kate welcome to Datapalooza!

# %% [markdown]
# 2. Realice la siguiente operación aritmética $\left(\frac{4-7}{3\cdot 5}\right)^2$.

# %%
(4-7/3*5)**2
# Out:
# 58.77777777777779

# %% [markdown]
# 3. Construya un programa donde le preguntes al usuario cuántas horas trabajó en Diciembre y el valor de su hora de trabajo. Luego que aparezca por pantalla el monto que le corresponde.

# %%
horas = float(input("Introduce tus horas de trabajo: "))
coste = float(input("Introduce lo que cobras por hora: "))
paga = horas * coste
print("Tu paga es", paga)
# Out:
# Introduce tus horas de trabajo: 10
# Introduce lo que cobras por hora: 17500
# Tu paga es 175000.0

# %% [markdown]
# 4. Construya un programa que pregunte al usuario el monto que desea invertir, el interés anual y el número de años, luego debe mostrar en la consola el capital que obtendrá por la inversión (Recuerde el interés debe expresarse de manera porcentual).

# %%
cantidad = float(input("¿Cantidad a invertir? "))
interes = float(input("¿Interés porcentual anual? "))
años = int(input("¿Años?"))
print("Capital final: " + str(round(cantidad * (interes / 100 + 1) ** años, 2)))
# Out:
# ¿Cantidad a invertir? 10000
# ¿Interés porcentual anual? 5
# ¿Años?3
# Capital final: 11576.25

# %% [markdown]
# 5. Escriba un programa que pregunte la edad que tiene, e imprima en la consola si mayor de edad o no lo es.

# %%
edad = int(input("¿Cuál es tu edad? "))
if edad < 18: 
    print ("Eres menor de edad.")
else:
    print("Eres mayor de edad.")

# %% [markdown]
# 6. En Europa del norte tienes la opción de empezar a trabajar desde los 16 años, con alguna serie de requisitos, por lo que debes pagar al SAKT un impuesto si percibes ingresos con un monto superior a 1500 € al mes. Contruya un programa que el pregunte al sujeto cuál es la edad que tiene y el ingreso que recibe, luego en pantalla debe mostrar si debe pagar el impuesto.

# %%
# solucion1
age = int(input("¿Cuál es tu edad? "))
income = float(input("¿Cuales son tus ingresos mensuales?"))
if age > 16 and income >= 1500:
    print("Tienes que pagar el impuesto")
else:
    print("No tienes que pagar el impuesto")
# Out:
# ¿Cuál es tu edad?  17
# ¿Cuales son tus ingresos mensuales? 1000
# Tienes que cotizar

# %%
# solucion2
age = int(input("¿Cuál es tu edad? "))
income = float(input("¿Cuales son tus ingresos mensuales?"))
if age <= 16 or income < 1000:
    print("No tienes que pagar impuesto")
else:
    print("Tienes que pagar impuesto")
# Out:
# ¿Cuál es tu edad?  16
# ¿Cuales son tus ingresos mensuales? 10000
# No tienes que cotizar

# %% [markdown]
# 7. El siguiente mes de abril se inicia la Operación Renta 2023 de los montos declarados en SII. Segun la tabla adjunta
#
# <img src="https://www.sii.cl/destacados/renta/2021/img/nuevotramorentamodernizacion.jpg" height="300">
#
#
# Construya un programa que pregunte al sujeto su Renta Imponible Anual y muestre en la consola el monto que se le descontará.

# %%
# Preguntar al usuario por la renta
renta = float(input("¿Cuál es tu renta anual? "))
# Condicional para determinar el tipo impositivo dependiendo de la renta
if renta < 8266698:
    factor = 0
elif renta < 18370440:
    factor = 0.04
elif renta < 30617400:
    factor = 0.08
elif renta < 42864360:
    factor = 0.135
elif renta < 55111320:
    factor = 0.23  
elif renta < 73481760:
    factor = 0.304
elif renta < 189827880:
    factor = 0.35  
else:
    factor = 0.4
# Mostrar por pantalla el producto de la renta por el tipo impositivo
print("Tienes que pagar ", "$", renta * factor,  sep='')
# Out:
# ¿Cuál es tu renta anual? 13000000
# Tienes que pagar $520000.0

# %% [markdown]
# 8. La pizzería Bella Napoli ofrece pizzas vegetarianas y no vegetarianas a sus clientes.
# Los ingredientes para cada tipo de pizza aparecen a continuación.
#
# - Ingredientes vegetarianos: Pimiento y tofu.
# - Ingredientes no vegetarianos: Peperoni, Jamón y Salmón.
#
# Escribir un programa que pregunte al usuario si quiere una pizza vegetariana o no, y en función de su respuesta le muestre un menú con los ingredientes disponibles para que elija.
# Solo se puede eligir un ingrediente además de la mozzarella y el tomate que están en todas la pizzas.
# Al final se debe mostrar por pantalla si la pizza elegida es vegetariana o no y todos los ingredientes que lleva.

# %%
# Presentación del menú con los tipos de pizza
print("Bienvenido a la pizzeria Bella Napoli.\nTipos de pizza\n\t1- Vegetariana\n\t2- No vegetariana\n")
tipo = input("Introduce el número correspondiente al tipo de pizza que quieres:")
# Decisión sobre el tipo de pizza
if tipo == "1":
    print("Ingredientes de pizzas vegetarianas\n\t 1- Pimiento\n\t2- Tofu\n")
    ingrediente = input("Introduce el ingrediente que deseas: ")
    print("Pizza vegetariana con mozzarella, tomate y ", end="")
    if ingrediente == "1":
        print("pimiento")
    else: 
        print("tofu")
else:
    print("Ingredientes de pizzas no vegetarianas\n\t1- Peperoni\n\t2- Jamón\n\t3- Salmón\n")
    ingrediente = input("Introduce el ingrediente que deseas: ")
    print("Pizza no vegetarina con mozarrella, tomate y ", end="")
    if ingrediente == "1":
        print("peperoni")
    elif ingrediente == "2":
        print("jamón")
    else:
        print("salmón")
# Out:
# Bienvenido a la pizzeria Bella Napoli.
# Tipos de pizza
# 	1- Vegetariana
# 	2- No vegetariana
#
# Introduce el número correspondiente al tipo de pizza que quieres:1
# Ingredientes de pizzas vegetarianas
# 	 1- Pimiento
# 	2- Tofu
#
# Introduce el ingrediente que deseas: Mozarella, Tofu, Tomate
# Pizza vegetariana con mozzarella, tomate y tofu

# %% [markdown]
# 9. Escribir un programa que pida al usuario una palabra y la muestre 10 veces por pantalla.

# %%
word = input("Introduce una palabra: ")
for i in range(10):
    print(word)
# Out:
# Introduce una palabra: Moin
# Moin
# Moin
# Moin
# Moin
# Moin
# Moin
# Moin
# Moin
# Moin
# Moin

# %% [markdown]
# 10. Cree un programa que le pida al usuario un número entero positivo y por pantalla aparezcan todos los números impares desde 1 hasta ese número separados por guiones cortos.

# %%
n = int(input("Introduce un número entero positivo: "))
for i in range(1, n+1, 2):
    print(i, end=" - ")
# Out:
# Introduce un número entero positivo: 15
# 1 - 3 - 5 - 7 - 9 - 11 - 13 - 15 -

# %% [markdown]
# 11. Imprima una figura tal que el usuario entregue la base y altura de un rectángulo, dibujado con (*), como el ejemplo de abajo.
#
# ```
# * * * * *
# * * * * *
# * * * * *
# ```

# %%
base = int(input("Base del rectángulo: "))
altura = int(input("Altura del rectángulo: "))

for i in range(altura):
    for j in range(base):
        print("* ", end="")
    print()
# Out:
# Base del rectángulo: 5
# Altura del rectángulo: 3
# * * * * *
# * * * * *
# * * * * *

# %% [markdown]
# 12. Cree una función que determine si el valor que recibe es par o impar

# %%
def paridad(numero):
    if numero%2==0:
        print(numero, "es un número par")
    else: 
        print(numero, "es un número impar")

paridad(-5)
# Out:
# -5 es un número impar

# %% [markdown]
# 13. Cree una función que reciba un número y devuelva `True` o `False` si es el valor recibido es impar o no.

# %%
def es_impar(numero):
    if numero%2==0:
        print(False)
    else: 
        print(True)

es_impar(8)
# Out:
# False

# %% [markdown]
# 14. Escribir una función que calcule el área de un círculo y otra que calcule el volumen de un cilindro usando la primera función (Use $\pi$ hasta con 4 decimales).

# %%
def circle_area(radius):
    pi = 3.1415
    return pi*radius**2

def cilinder_volume(radius, high):
    return circle_area(radius)*high

print(cilinder_volume(3,5))
# Out:
# 282.735

# %% [markdown]
# 15. Recuerda el ejercicio de la Operación renta, pues hemos olvidado considerar que a partir de este año, a las boletas emitidas se les aplicará también un porcentaje de impuesto extra conocido como IVA. Cree una función que recibir la renta del trabajador, devolviendo el detalle del monto con el porcentaje de IVA aplicado, el cálculo del factor entregado antes y la suma de ambos descuentos.

# %%
def SII(renta):
    if renta < 8266698:
        factor = 0
    elif renta < 18370440:
        factor = 0.04
    elif renta < 30617400:
        factor = 0.08
    elif renta < 42864360:
        factor = 0.135
    elif renta < 55111320:
        factor = 0.23  
    elif renta < 73481760:
        factor = 0.304
    elif renta < 189827880:
        factor = 0.35  
    else:
        factor = 0.4

    desc1 = renta*factor
    desc2 = renta*0.19
    return print("Descuento factor: ",desc1,"\n Descuento IVA: ", desc2, "\n Descuento Total: ", desc1 + desc2)

# %%
SII(8000000)
# Out:
# Descuento factor:  0
#  Descuento IVA:  1520000.0
#  Descuento Total:  1520000.0
